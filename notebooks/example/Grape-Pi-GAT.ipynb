# %%
import os
from graphgym.custom_graphgym.loader.protein import ProteinDataset

# %%
os.chdir('/Users/cgu3/Documents/Grape-Pi')

# %%
dataset = ProteinDataset("data/gastric-multi-graph", numeric_columns=['protein_probability'], label_column='protein_probability_soft_label', rebuild=True)
# dataset = ProteinDataset("data/yeast-ORBI", numeric_columns=['protein_probability'], label_column=None, rebuild=True)
# dataset = ProteinDataset("data/human-ORBI", numeric_columns=['protein_probability'], label_column='label', rebuild=True)
# dataset = ProteinDataset("data/yeast-ORBI", numeric_columns=['protein_probability', 'mRNA_TPM'], label_column=None, rebuild=True)
# Out:
# Rebuilding...
# Done!

# %%
from matplotlib import pyplot as plt
from torch_geometric.utils import  degree
plt.hist(degree(dataset.edge_index[0]), bins=100);

# %%
plt.hist(dataset.x[:, 0], bins=100);

# %%
dataset.num_features
# Out:
# 1

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(dataset, batch_size=1, shuffle=True)
test_loader = DataLoader(dataset, batch_size=1, shuffle=False)
val_loader = DataLoader(dataset, batch_size=1, shuffle=False)

# %%
import os.path as osp
import time

import torch
import torch.nn.functional as F
from sklearn.metrics import f1_score

from torch_geometric.datasets import PPI
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GATConv


class Net(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = GATConv(dataset.num_features, 10, heads=4)
        self.lin1 = torch.nn.Linear(dataset.num_features, 4 * 10)
        # self.conv2 = GATConv(4 * 256, 256, heads=4)
        # self.lin2 = torch.nn.Linear(4 * 256, 4 * 256)
        self.conv3 = GATConv(4 * 10, 1, heads=6,
                             concat=False)
        self.lin3 = torch.nn.Linear(4 * 10, 1)

    def forward(self, x, edge_index):
        x = F.elu(self.conv1(x, edge_index) + self.lin1(x))
        # x = F.elu(self.conv2(x, edge_index) + self.lin2(x))
        x = self.conv3(x, edge_index) + self.lin3(x)
        return x


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net().to(device)
loss_op = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)


def train():
    model.train()

    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        loss = loss_op(model(data.x, data.edge_index).squeeze(-1), data.y)
        total_loss += loss.item() * data.num_graphs
        loss.backward()
        optimizer.step()
    return total_loss


@torch.no_grad()
def test(loader):
    model.eval()

    ys, preds = [], []
    for data in loader:
        ys.append(data.y)
        out = model(data.x.to(device), data.edge_index.to(device))
        preds.append(torch.nn.functional.sigmoid(out))

    y, pred = torch.cat(ys, dim=0).numpy(), torch.cat(preds, dim=0).numpy()
    y, pred = torch.tensor(y), torch.tensor(pred)
    return loss_op(y, pred.squeeze(-1))


times = []
for epoch in range(1, 101):
    start = time.time()
    loss = train()
    val_f1 = test(val_loader)
    test_f1 = test(test_loader)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Val: {val_f1:.4f}, '
          f'Test: {test_f1:.4f}')
    times.append(time.time() - start)
print(f"Median time per epoch: {torch.tensor(times).median():.4f}s")
# Out:
# Epoch: 001, Loss: 1.2447, Val: 0.5539, Test: 0.5539
# Epoch: 002, Loss: 1.2009, Val: 0.5325, Test: 0.5325
# Epoch: 003, Loss: 1.1905, Val: 0.5590, Test: 0.5590
# Epoch: 004, Loss: 1.1446, Val: 0.6032, Test: 0.6032
# Epoch: 005, Loss: 1.1333, Val: 0.6311, Test: 0.6311
# Epoch: 006, Loss: 1.1362, Val: 0.6223, Test: 0.6223
# Epoch: 007, Loss: 1.1204, Val: 0.5948, Test: 0.5948
(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Val: {val_f1:.4f}, '
#      73       f'Test: {test_f1:.4f}')
#      74 times.append(time.time() - start)
#
# File ~/opt/anaconda3/envs/Grape-Pi/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[122], line 56, in test(loader)
#      53 model.eval()
#      55 ys, preds = [], []
# ---> 56 for data in loader:
#      57     ys.append(data.y)
#      58     out = model(data.x.to(device), data.edge_index.to(device))
#
# File ~/opt/anaconda3/envs/Grape-Pi/lib/python3.10/site-packages/torch/utils/data/dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/opt/anaconda3/envs/Grape-Pi/lib/python3.10/site-packages/torch/utils/data/dataloader.py:678, in _SingleProcessDataLoaderIter._next_data(self)
#     676 def _next_data(self):
#     677     index = self._next_index()  # may raise StopIteration
# --> 678     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679     if self._pin_memory:
#     680         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/opt/anaconda3/envs/Grape-Pi/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File ~/Documents/Grape-Pi/torch_geometric/loader/dataloader.py:52, in Collater.collate_fn(self, batch)
#      50 if isinstance(self.dataset, OnDiskDataset):
#      51     return self(self.dataset.multi_get(batch))
# ---> 52 return self(batch)
#
# File ~/Documents/Grape-Pi/torch_geometric/loader/dataloader.py:27, in Collater.__call__(self, batch)
#      25 elem = batch[0]
#      26 if isinstance(elem, BaseData):
# ---> 27     return Batch.from_data_list(
#      28         batch,
#      29         follow_batch=self.follow_batch,
#      30         exclude_keys=self.exclude_keys,
#      31     )
#      32 elif isinstance(elem, torch.Tensor):
#      33     return default_collate(batch)
#
# File ~/Documents/Grape-Pi/torch_geometric/data/batch.py:93, in Batch.from_data_list(cls, data_list, follow_batch, exclude_keys)
#      81 @classmethod
#      82 def from_data_list(cls, data_list: List[BaseData],
#      83                    follow_batch: Optional[List[str]] = None,
#      84                    exclude_keys: Optional[List[str]] = None):
#      85     r"""Constructs a :class:`~torch_geometric.data.Batch` object from a
#      86     Python list of :class:`~torch_geometric.data.Data` or
#      87     :class:`~torch_geometric.data.HeteroData` objects.
#    (...)
#      90     :obj:`follow_batch`.
#      91     Will exclude any keys given in :obj:`exclude_keys`."""
# ---> 93     batch, slice_dict, inc_dict = collate(
#      94         cls,
#      95         data_list=data_list,
#      96         increment=True,
#      97         add_batch=not isinstance(data_list[0], Batch),
#      98         follow_batch=follow_batch,
#      99         exclude_keys=exclude_keys,
#     100     )
#     102     batch._num_graphs = len(data_list)
#     103     batch._slice_dict = slice_dict
#
# File ~/Documents/Grape-Pi/torch_geometric/data/collate.py:87, in collate(cls, data_list, increment, add_batch, follow_batch, exclude_keys)
#      84     continue
#      86 # Collate attributes into a unified representation:
# ---> 87 value, slices, incs = _collate(attr, values, data_list, stores,
#      88                                increment)
#      90 if isinstance(value, Tensor) and value.is_cuda:
#      91     device = value.device
#
# File ~/Documents/Grape-Pi/torch_geometric/data/collate.py:206, in _collate(key, values, data_list, stores, increment)
#     204     value_dict, slice_dict, inc_dict = {}, {}, {}
#     205     for key in elem.keys():
# --> 206         value_dict[key], slice_dict[key], inc_dict[key] = _collate(
#     207             key, [v[key] for v in values], data_list, stores, increment)
#     208     return value_dict, slice_dict, inc_dict
#     210 elif (isinstance(elem, Sequence) and not isinstance(elem, str)
#     211       and len(elem) > 0 and isinstance(elem[0], (Tensor, SparseTensor))):
#     212     # Recursively collate elements of lists.
#
# File ~/Documents/Grape-Pi/torch_geometric/data/collate.py:134, in _collate(key, values, data_list, stores, increment)
#     132 if cat_dim is None or elem.dim() == 0:
#     133     values = [value.unsqueeze(0) for value in values]
# --> 134 sizes = torch.tensor([value.size(cat_dim or 0) for value in values])
#     135 slices = cumsum(sizes)
#     136 if increment:
#
# KeyboardInterrupt:
